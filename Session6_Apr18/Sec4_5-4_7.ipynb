# %% [markdown]
# # Section 4.5-4.7 (or so)

# %% [markdown]
# Erik Tollerud (@eteq)

# %%
#setup stuff
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#interact only works for ipython 2.0 
from IPython.html.widgets import interact
have_interact = True

# %%
from astroML.resample import bootstrap, jackknife
from astroML.stats import sigmaG
from astroML import plotting
from scipy import stats

# %% [markdown]
# ## Playing with Bootstrap

# %%
#plotting function for below
def bootstrap_hists(distribution, n_samples, n_boot, 
                    lim_data=None, lim_loc=None, lim_scale=None, 
                    figsize=None, bins=None):
    data = distribution.rvs(n_samples)
    
    mean_boot = bootstrap(data, n_boot, lambda x: np.mean(x,axis=1))
    med_boot = bootstrap(data, n_boot, lambda x: np.median(x,axis=1))
    
    std_boot = bootstrap(data, n_boot, lambda x: np.std(x,axis=1))
    sigG_boot = bootstrap(data, n_boot, lambda x: sigmaG(x,axis=1))
    
    if figsize:
        plt.figure(figsize=figsize)
        
    plt.subplot(2,2,1)
    
    if bins and lim_data:
        bins_data = np.linspace(lim_data[0], lim_data[1], bins)
    else:
        bins_data = 'freedman'
        
    plotting.hist(data, histtype='step',bins=bins_data)
    plt.title('Data')
    
    if lim_data:
        plt.xlim(*lim_data)
    
    
    plt.subplot(2,2,3)
    
    if bins and lim_loc:
        bins_loc = np.linspace(lim_loc[0], lim_loc[1], bins)
    else:
        bins_loc = 'freedman'
        
    bins_loc = plotting.hist(mean_boot, histtype='step',label='mean',bins=bins_loc)[1]
    plt.hist(med_boot, histtype='step',label='median', bins=bins_loc)
    plt.title('Bootstrap loc')

    plt.legend(loc=0)
    if lim_loc:
        plt.xlim(*lim_loc)
    
    plt.subplot(2,2,4)
    
    if bins and lim_scale:
        bins_scale = np.linspace(lim_scale[0], lim_scale[1], bins)
    else:
        bins_scale = 'freedman'
        
    bins_scale = plotting.hist(std_boot, histtype='step',label='std',bins=bins_scale)[1]
    plt.hist(sigG_boot, histtype='step',label='sigG', bins=bins_scale)
    plt.title('Bootstrap scale')
    
    plt.legend(loc=0)
    if lim_scale:
        plt.xlim(*lim_scale)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Gaussian

# %%
distribution = stats.norm(scale=1,loc=0)

figsize = (12,12)
lim_data = (-3, 3)
lim_loc = (-.7,.7) # range for the "location" statistics
lim_scale = (0.5,1.5) # range for the "scale" statistics
bins = 100

if not have_interact:
    plt.figure(figsize=figsize)
    #need to change the values and re-compute if you can't interact
    bootstrap_hists(distribution, 
                    n_samples=100, n_boot=10000, 
                    lim_data=lim_data, lim_loc=lim_loc, lim_scale=lim_scale)
else:
    def f(**kwargs):
        kwargs['lim_data'] = lim_data
        kwargs['lim_loc'] = lim_loc
        kwargs['lim_scale'] = lim_scale
        kwargs['figsize'] = figsize
        kwargs['bins'] = bins
        bootstrap_hists(distribution, **kwargs)
    interact(f, n_samples=(3,1000), n_boot=(5,1000))

# %% [markdown]
# ### Uniform

# %%
distribution = stats.uniform(scale=2, loc=-1) # from -1 to 1

figsize = (12,12)
lim_data = (-1.1, 1.1)
lim_loc = (-.7,.7) # range for the "location" statistics
lim_scale = (0.25,1.5) # range for the "scale" statistics
bins = 100

if not have_interact:
    plt.figure(figsize=figsize)
    #need to change the values and re-compute if you can't interact
    bootstrap_hists(distribution, 
                    n_samples=100, n_boot=10000, 
                    lim_data=lim_data, lim_loc=lim_loc, lim_scale=lim_scale)
else:
    def f(**kwargs):
        kwargs['lim_data'] = lim_data
        kwargs['lim_loc'] = lim_loc
        kwargs['lim_scale'] = lim_scale
        kwargs['figsize'] = figsize
        kwargs['bins'] = bins
        bootstrap_hists(distribution, **kwargs)
    interact(f, n_samples=(3,1000), n_boot=(5,1000))

# %% [markdown]
# ### Beta

# %%
distribution = stats.beta(3, 2, scale=2, loc=-1)

figsize = (12,12)
lim_data = (-1.1, 1.1)
lim_loc = (-.7,.7) # range for the "location" statistics
lim_scale = (0.,1.0) # range for the "scale" statistics
bins = 50

if not have_interact:
    plt.figure(figsize=figsize)
    #need to change the values and re-compute if you can't interact
    bootstrap_hists(distribution, 
                    n_samples=100, n_boot=10000, 
                    lim_data=lim_data, lim_loc=lim_loc, lim_scale=lim_scale)
else:
    def f(**kwargs):
        kwargs['lim_data'] = lim_data
        kwargs['lim_loc'] = lim_loc
        kwargs['lim_scale'] = lim_scale
        kwargs['figsize'] = figsize
        kwargs['bins'] = bins
        bootstrap_hists(distribution, **kwargs)
    interact(f, n_samples=(3,1000), n_boot=(5,1000))

# %% [markdown]
# ### Cauchy

# %%
distribution = stats.cauchy(loc=0, scale=1)

figsize = (12,12)
lim_data = (-3, 3)
lim_loc = (-.7,.7) # range for the "location" statistics
lim_scale = (0.,20) # range for the "scale" statistics
bins = 100

if not have_interact:
    plt.figure(figsize=figsize)
    #need to change the values and re-compute if you can't interact
    bootstrap_hists(distribution, 
                    n_samples=100, n_boot=10000, 
                    lim_data=lim_data, lim_loc=lim_loc, lim_scale=lim_scale)
else:
    def f(**kwargs):
        kwargs['lim_data'] = lim_data
        kwargs['lim_loc'] = lim_loc
        kwargs['lim_scale'] = lim_scale
        kwargs['figsize'] = figsize
        kwargs['bins'] = bins
        bootstrap_hists(distribution, **kwargs)
    interact(f, n_samples=(3,1000), n_boot=(5,1000))

# %% [markdown]
# ## Jackknife

# %%
data=np.random.randn(100)
jackknife(data,lambda x: np.std(x,axis=1),return_raw_distribution=True)
# Out:
# (0.85816684646753594,
#  0.058270440066030972,
#  array([ 0.85396144,  0.84539195,  0.84998362,  0.85167938,  0.8560977 ,
#          0.85006282,  0.85290485,  0.85605464,  0.85480634,  0.84365159,
#          0.8361542 ,  0.85450001,  0.85455013,  0.84128057,  0.85605619,
#          0.85533093,  0.85377688,  0.85164951,  0.85612226,  0.85495501,
#          0.85016715,  0.85488598,  0.83828905,  0.85609592,  0.83350077,
#          0.84686321,  0.84327325,  0.85600677,  0.85476704,  0.85176365,
#          0.85602231,  0.84436206,  0.84995881,  0.85549727,  0.85611513,
#          0.8548301 ,  0.85530427,  0.8540817 ,  0.85399901,  0.85119821,
#          0.8486683 ,  0.85554982,  0.85342202,  0.85608052,  0.85236738,
#          0.85594423,  0.85588349,  0.82808191,  0.85532356,  0.85483308,
#          0.85522463,  0.85590404,  0.83193684,  0.83213267,  0.85254016,
#          0.85611527,  0.84995056,  0.85543499,  0.85489174,  0.84934969,
# ...

# %%
#plotting function for below
def jackknife_hists(distribution, n_samples, 
                    lim_data=None, lim_loc=None, lim_scale=None, 
                    figsize=None, bins=None):
    data = distribution.rvs(n_samples)
    
    mean_jack = jackknife(data, lambda x: np.mean(x,axis=1), return_raw_distribution=True)
    med_jack = jackknife(data, lambda x: np.median(x,axis=1), return_raw_distribution=True)
    
    std_jack = jackknife(data, lambda x: np.std(x,axis=1), return_raw_distribution=True)
    sigG_jack = jackknife(data, lambda x: sigmaG(x,axis=1), return_raw_distribution=True)
    
    if figsize:
        plt.figure(figsize=figsize)
        
    plt.subplot(2,2,1)
    
    if bins and lim_data:
        bins_data = np.linspace(lim_data[0], lim_data[1], bins)
    else:
        bins_data = 'freedman'
        
    plotting.hist(data, histtype='step',bins=bins_data)
    plt.title('Data')
    
    if lim_data:
        plt.xlim(*lim_data)
    
    
    plt.subplot(2,2,3)
    
    if bins and lim_loc:
        bins_loc = np.linspace(lim_loc[0], lim_loc[1], bins)
    else:
        bins_loc = 'freedman'
        
    bins_loc = plotting.hist(mean_jack[-1], histtype='step',label='mean',bins=bins_loc)[1]
    plt.hist(med_jack[-1], histtype='step',label='median', bins=bins_loc)
    
    plt.axvline(mean_jack[0], color='b', linestyle=':')
    plt.axvline(mean_jack[0]-mean_jack[1], color='b', linestyle='--')
    plt.axvline(mean_jack[0]+mean_jack[1], color='b', linestyle='--')
    
    plt.axvline(med_jack[0], color='g', linestyle=':')
    plt.axvline(med_jack[0]-med_jack[1], color='g', linestyle='--')
    plt.axvline(med_jack[0]+med_jack[1], color='g', linestyle='--')
    
    plt.title('Jackknife loc')

    plt.legend(loc=0)
    if lim_loc:
        plt.xlim(*lim_loc)
    
    plt.subplot(2,2,4)
    
    if bins and lim_scale:
        bins_scale = np.linspace(lim_scale[0], lim_scale[1], bins)
    else:
        bins_scale = 'freedman'
        
    bins_scale = plotting.hist(std_jack[-1], histtype='step',label='std',bins=bins_scale)[1]
    plt.hist(sigG_jack[-1], histtype='step',label='sigG', bins=bins_scale)
    
    
    plt.axvline(std_jack[0], color='b', linestyle=':')
    plt.axvline(std_jack[0]-std_jack[1], color='b', linestyle='--')
    plt.axvline(std_jack[0]+std_jack[1], color='b', linestyle='--')
    
    plt.axvline(sigG_jack[0], color='g', linestyle=':')
    plt.axvline(sigG_jack[0]-sigG_jack[1], color='g', linestyle='--')
    plt.axvline(sigG_jack[0]+sigG_jack[1], color='g', linestyle='--')
    
    plt.title('Jackknife scale')
    
    plt.legend(loc=0)
    if lim_scale:
        plt.xlim(*lim_scale)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Gaussian

# %%
distribution = stats.norm(scale=1,loc=0)

figsize = (12,12)
lim_data = (-3, 3)
lim_loc = (-.1,.1) # range for the "location" statistics
lim_scale = (0.9,1.1) # range for the "scale" statistics
bins = 100

if not have_interact:
    plt.figure(figsize=figsize)
    #need to change the values and re-compute if you can't interact
    jackknife_hists(distribution, 
                    n_samples=100, n_boot=10000, 
                    lim_data=lim_data, lim_loc=lim_loc, lim_scale=lim_scale)
else:
    def f(**kwargs):
        kwargs['lim_data'] = lim_data
        kwargs['lim_loc'] = lim_loc
        kwargs['lim_scale'] = lim_scale
        kwargs['figsize'] = figsize
        kwargs['bins'] = bins
        jackknife_hists(distribution, **kwargs)
    interact(f, n_samples=(3,1000))

# %% [markdown]
# ### Uniform

# %%
distribution = stats.uniform(scale=2, loc=-1) # from -1 to 1

figsize = (12,12)
lim_data = (-1.1, 1.1)
lim_loc = (-.7,.7) # range for the "location" statistics
lim_scale = (0.25,1.5) # range for the "scale" statistics
bins = 100

if not have_interact:
    plt.figure(figsize=figsize)
    #need to change the values and re-compute if you can't interact
    jackknife_hists(distribution, 
                    n_samples=100,
                    lim_data=lim_data, lim_loc=lim_loc, lim_scale=lim_scale)
else:
    def f(**kwargs):
        kwargs['lim_data'] = lim_data
        kwargs['lim_loc'] = lim_loc
        kwargs['lim_scale'] = lim_scale
        kwargs['figsize'] = figsize
        kwargs['bins'] = bins
        jackknife_hists(distribution, **kwargs)
    interact(f, n_samples=(3,1000))

# %% [markdown]
# ### Beta

# %%
distribution = stats.beta(3, 2, scale=2, loc=-1)

figsize = (12,12)
lim_data = (-1.1, 1.1)
lim_loc = (-.3,.3) # range for the "location" statistics
lim_scale = (0.3,0.7) # range for the "scale" statistics
bins = 50

if not have_interact:
    plt.figure(figsize=figsize)
    #need to change the values and re-compute if you can't interact
    jackknife_hists(distribution, 
                    n_samples=100, 
                    lim_data=lim_data, lim_loc=lim_loc, lim_scale=lim_scale)
else:
    def f(**kwargs):
        kwargs['lim_data'] = lim_data
        kwargs['lim_loc'] = lim_loc
        kwargs['lim_scale'] = lim_scale
        kwargs['figsize'] = figsize
        kwargs['bins'] = bins
        jackknife_hists(distribution, **kwargs)
    interact(f, n_samples=(3,1000))

# %% [markdown]
# ### Cauchy

# %%
distribution = stats.cauchy(loc=0, scale=1)

figsize = (12,12)
lim_data = (-3, 3)
lim_loc = (-5,5) # range for the "location" statistics
lim_scale = (0.,50) # range for the "scale" statistics
bins = 100

if not have_interact:
    plt.figure(figsize=figsize)
    #need to change the values and re-compute if you can't interact
    jackknife_hists(distribution, 
                    n_samples=100,
                    lim_data=lim_data, lim_loc=lim_loc, lim_scale=lim_scale)
else:
    def f(**kwargs):
        kwargs['lim_data'] = lim_data
        kwargs['lim_loc'] = lim_loc
        kwargs['lim_scale'] = lim_scale
        kwargs['figsize'] = figsize
        kwargs['bins'] = bins
        jackknife_hists(distribution, **kwargs)
    interact(f, n_samples=(3,1000))

# %% [markdown]
# ## AstroML figures

# %%
"""
Example of classification
-------------------------
Figure 4.5.

An example of a simple classification problem between two Gaussian
distributions. Given a value of x, we need to assign that measurement to one
of the two distributions (background vs. source). The cut at xc = 120 leads
to very few Type II errors (i.e., false negatives: points from the distribution
hS with x < xc being classified as background), but this comes at the cost of
a significant number of Type I errors (i.e., false positives: points from the
distribution :math:`h_B` with x > xc being classified as sources).
"""
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=True)

#------------------------------------------------------------
# Generate and draw the curves
x = np.linspace(50, 200, 1000)
p1 = 0.9 * norm(100, 10).pdf(x)
p2 = 0.1 * norm(150, 12).pdf(x)

fig, ax = plt.subplots(figsize=(10, 8))
ax.fill(x, p1, ec='k', fc='#AAAAAA', alpha=0.5)
ax.fill(x, p2, '-k', fc='#AAAAAA', alpha=0.5)

ax.plot([120, 120], [0.0, 0.04], '--k')

ax.text(100, 0.036, r'$h_B(x)$', ha='center', va='bottom')
ax.text(150, 0.0035, r'$h_S(x)$', ha='center', va='bottom')
ax.text(122, 0.039, r'$x_c=120$', ha='left', va='top')
ax.text(125, 0.01, r'$(x > x_c\ {\rm classified\ as\ sources})$')

ax.set_xlim(50, 200)
ax.set_ylim(0, 0.04)

ax.set_xlabel('$x$')
ax.set_ylabel('$p(x)$')
plt.show()

# %%
r"""
Example of Benjamini & Hochberg Method
--------------------------------------
Figure 4.6.

Illustration of the Benjamini and Hochberg method for 106 points drawn from
the distribution shown in figure 4.5. The solid line shows the cumulative
distribution of observed p values, normalized by the sample size. The dashed
lines show the cutoff for various limits on contamination rate
:math:`\varepsilon` computed using eq. 4.44 (the accepted measurements are
those with p smaller than that corresponding to the intersection of solid and
dashed curves). The dotted line shows how the distribution would look in the
absence of sources. The value of the cumulative distribution at p = 0.5 is
0.55, and yields a correction factor :math:`\lambda = 1.11` (see eq. 4.46).
"""
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=True)

#------------------------------------------------------------
# Set up the background and foreground distributions
background = norm(100, 10)
foreground = norm(150, 12)
f = 0.1

# Draw from the distribution
N = 1E6
X = np.random.random(N)
mask = (X < 0.1)
X[mask] = foreground.rvs(np.sum(mask))
X[~mask] = background.rvs(np.sum(~mask))

#------------------------------------------------------------
# Perform Benjamini-Hochberg method
p = 1 - background.cdf(X)
p_sorted = np.sort(p)

#------------------------------------------------------------
# plot the results
fig = plt.figure(figsize=(10, 8))
fig.subplots_adjust(bottom=0.15)
ax = plt.axes(xscale='log', yscale='log')

# only plot every 1000th; plotting all 1E6 takes too long
ax.plot(p_sorted[::1000], np.linspace(0, 1, 1000), '-k')
ax.plot(p_sorted[::1000], p_sorted[::1000], ':k', lw=1)

# plot the cutoffs for various values of expsilon
p_reg_over_eps = 10 ** np.linspace(-3, 0, 100)
for (i, epsilon) in enumerate([0.1, 0.01, 0.001, 0.0001]):
    x = p_reg_over_eps * epsilon
    y = p_reg_over_eps
    ax.plot(x, y, '--k')

    ax.text(x[1], y[1],
            r'$\epsilon = %.1g$' % epsilon,
            ha='center', va='bottom', rotation=70)

ax.xaxis.set_major_locator(plt.LogLocator(base=100))

ax.set_xlim(1E-15, 1)
ax.set_ylim(1E-3, 1)

ax.set_xlabel('$p = 1 - H_B(i)$')
ax.set_ylabel('normalized $C(p)$')

plt.show()
# Out:
# -c:43: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
"""
Gaussianity Tests
-----------------
Figure 4.7.

The results of the Anderson-Darling test, the Kolmogorov-Smirnov test, and the
Shapiro-Wilk test when applied to a sample of 10,000 values drawn from a normal
distribution (upper panel) and from a combination of two Gaussian distributions
(lower panel).

The functions are available in the ``scipy`` package:

- The Anderson-Darling test (``scipy.stats.anderson``)
- The Kolmogorov-Smirnov test (``scipy.stats.kstest``)
- The Shapiro-Wilk test (``scipy.stats.shapiro``)
"""
# Author: Jake VanderPlas
# License: BSD
#   The figure produced by this code is published in the textbook
#   "Statistics, Data Mining, and Machine Learning in Astronomy" (2013)
#   For more information, see http://astroML.github.com
#   To report a bug or issue, use the following forum:
#    https://groups.google.com/forum/#!forum/astroml-general
import numpy as np
from scipy import stats
from matplotlib import pyplot as plt

#----------------------------------------------------------------------
# This function adjusts matplotlib settings for a uniform feel in the textbook.
# Note that with usetex=True, fonts are rendered with LaTeX.  This may
# result in an error if LaTeX is not installed on your system.  In that case,
# you can set usetex to False.
from astroML.plotting import setup_text_plots
setup_text_plots(fontsize=8, usetex=True)

from astroML.stats import mean_sigma, median_sigmaG

# create some distributions
np.random.seed(1)
normal_vals = stats.norm(loc=0, scale=1).rvs(10000)
dual_vals = stats.norm(0, 1).rvs(10000)
dual_vals[:4000] = stats.norm(loc=3, scale=2).rvs(4000)

x = np.linspace(-4, 10, 1000)
normal_pdf = stats.norm(0, 1).pdf(x)
dual_pdf = 0.6 * stats.norm(0, 1).pdf(x) + 0.4 * stats.norm(3, 2).pdf(x)

vals = [normal_vals, dual_vals]
pdf = [normal_pdf, dual_pdf]
xlims = [(-4, 4), (-4, 10)]


#------------------------------------------------------------
# Compute the statistics and plot the results
fig = plt.figure(figsize=(5, 7))
fig.subplots_adjust(left=0.13, right=0.95,
                    bottom=0.06, top=0.95,
                    hspace=0.1)

for i in range(2):
    ax = fig.add_subplot(2, 1, 1 + i)  # 2 x 1 subplot

    # compute some statistics
    A2, sig, crit = stats.anderson(vals[i])
    D, pD = stats.kstest(vals[i], "norm")
    W, pW = stats.shapiro(vals[i])

    mu, sigma = mean_sigma(vals[i], ddof=1)
    median, sigmaG = median_sigmaG(vals[i])

    N = len(vals[i])
    Z1 = 1.3 * abs(mu - median) / sigma * np.sqrt(N)
    Z2 = 1.1 * abs(sigma / sigmaG - 1) * np.sqrt(N)

    print 70 * '_'
    print "  Kolmogorov-Smirnov test: D = %.2g  p = %.2g" % (D, pD)
    print "  Anderson-Darling test: A^2 = %.2g" % A2
    print "    significance  | critical value "
    print "    --------------|----------------"
    for j in range(len(sig)):
        print "    %.2f          | %.1f%%" % (sig[j], crit[j])
    print "  Shapiro-Wilk test: W = %.2g p = %.2g" % (W, pW)
    print "  Z_1 = %.1f" % Z1
    print "  Z_2 = %.1f" % Z2

    # plot a histogram
    ax.hist(vals[i], bins=50, normed=True, histtype='stepfilled', alpha=0.5)
    ax.plot(x, pdf[i], '-k')
    ax.set_xlim(xlims[i])

    # print information on the plot
    info = "Anderson-Darling: $A^2 = %.2f$\n" % A2
    info += "Kolmogorov-Smirnov: $D = %.2g$\n" % D
    info += "Shapiro-Wilk: $W = %.2g$\n" % W
    info += "$Z_1 = %.1f$\n$Z_2 = %.1f$" % (Z1, Z2)
    ax.text(0.97, 0.97, info,
            ha='right', va='top', transform=ax.transAxes)

    if i == 0:
        ax.set_ylim(0, 0.55)
    else:
        ax.set_ylim(0, 0.35)
        ax.set_xlabel('$x$')

    ax.set_ylabel('$p(x)$')

plt.show()
# Out:
# ______________________________________________________________________
#   Kolmogorov-Smirnov test: D = 0.0076  p = 0.6
#   Anderson-Darling test: A^2 = 0.29
#     significance  | critical value
#     --------------|----------------
#     0.58          | 15.0%
#     0.66          | 10.0%
#     0.79          | 5.0%
#     0.92          | 2.5%
#     1.09          | 1.0%
#   Shapiro-Wilk test: W = 1 p = 0.59
#   Z_1 = 0.2
#   Z_2 = 1.0
# ______________________________________________________________________
#   Kolmogorov-Smirnov test: D = 0.28  p = 0
#   Anderson-Darling test: A^2 = 1.9e+02
#     significance  | critical value
#     --------------|----------------
#     0.58          | 15.0%
#     0.66          | 10.0%
#     0.79          | 5.0%
#     0.92          | 2.5%
#     1.09          | 1.0%
#   Shapiro-Wilk test: W = 0.94 p = 0
#   Z_1 = 32.2
#   Z_2 = 2.5

# %% [markdown]
# ## A bit more on the K-S test

# %%
plt.figure(figsize=(8,8))
bins = np.linspace(-6,6,100)
plt.hist(normal_vals, histtype='step', color='b', bins=bins)
plt.hist(dual_vals, histtype='step', color='g', bins=bins);

# %%
plt.figure(figsize=(8,8))

plt.plot(np.sort(normal_vals),np.linspace(0,1,len(normal_vals)), linestyle='steps-mid')
plt.plot(np.sort(dual_vals),np.linspace(0,1,len(normal_vals)), linestyle='steps-mid')

stats.ks_2samp(normal_vals, dual_vals)
# Out:
# (0.28129999999999999, 0.0)

# %%
def ks_test_mc(n_samples, n_KSs):
    plt.figure(figsize=(12,6))
    
    Ds = []
    ps = []
    for data1, data2 in np.random.randn(n_KSs, 2, n_samples):
        D, p = stats.ks_2samp(data1, data2)
        Ds.append(D)
        ps.append(p)
    
    bins = np.linspace(0,1, 101)
    
    plt.subplot(1,2,1)
    plotting.hist(ps, histtype='step', bins=bins)
    plt.title('p-values')
    plt.xlim(0, 1)
    
    plt.subplot(1,2,2)
    plotting.hist(Ds, histtype='step', bins='freedman')
    plt.title('Ds')
    
    plt.show()

# %%
if not have_interact:
    #need to change the values and re-compute if you can't interact
    ks_test_mc(100, 100)
else:
    interact(ks_test_mc, n_samples=(3,1000), n_KSs=(10,1000))
